# %%
import pandas as pd
import numpy as np
import re
import matplotlib
import matplotlib.pyplot as plt

# %%
matches = pd.read_csv('data_prepared.csv')

# %%
matches
# Out:
#        assists_p0  assists_p1  assists_p2  assists_p3  assists_p4  assists_p5  \
# 0               3           6           1           0           1           3
# 1               3           3           4           4           4           2
# 2               3           3           7           3           5           6
# 3               5           3           4           4           5           3
# 4               5           4           2           3           4           5
# 5               1           4           5           2           2           0
# 6               4           4           3           3           7           5
# 7               4           1           4           4           2           2
# 8               1           3           3           5           2           4
# 9               0           2           5           3           1           4
# 10              2           3           4           9           4           2
# ...
